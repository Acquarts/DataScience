# %% [markdown]
# <a href="https://colab.research.google.com/github/Acquarts/DataScience/blob/main/Thyroid_Cancer_Recurrence.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## THYROID CANCER RECURRENCE | Predictive and Analytic Model

# %% [markdown]
# # Thyroid Cancer Recurrence Prediction
#
# This project analyzes clinical data from thyroid cancer patients to predict recurrence after radioactive iodine (RAI) therapy. It explores patterns, answers key clinical questions, and trains machine learning models for predictive purposes.
#
# ## 📁 About the Dataset
#
# This dataset focuses on thyroid cancer recurrence after Radioactive Iodine (RAI) therapy. It contains 383 patient records with 13 key attributes, including age, gender, cancer staging, pathology type, risk classification, treatment response, and recurrence status. The data is valuable for predicting cancer recurrence, understanding risk factors, and evaluating treatment outcomes.
#
# ### 📊 Dataset Overview
# - 📌 Total Rows: 383
# - 📌 Total Columns: 13
# - 📌 No Missing Values
#
# ### 🔹 Column Descriptions
# - **Age**: Age of the patient (in years)
# - **Gender**: Patient's gender (Male or Female)
# - **Hx Radiotherapy**: History of prior radiotherapy (Yes or No)
# - **Adenopathy**: Presence of lymph node involvement (Yes or No)
# - **Pathology**: Type of thyroid cancer (e.g., Micropapillary)
# - **Focality**: Tumor focality (Uni-Focal or Multi-Focal)
# - **Risk**: Cancer risk classification (Low, Intermediate, High)
# - **T**: Tumor classification (T1, T2, etc.)
# - **N**: Lymph node classification (N0, N1, etc.)
# - **M**: Metastasis classification (M0, M1, etc.)
# - **Stage**: Cancer staging (Stage I, II, III, IV)
# - **Response**: Treatment response (Excellent, Indeterminate, etc.)
# - **Recurred**: Whether cancer recurred (Yes or No)
#
# ## ❓ Key Questions to Explore
#
# 1️⃣ Are thyroid cancer recurrences more common in men or women?
# 2️⃣ How does age affect recurrence risk?
# 3️⃣ Can we predict recurrence based on tumor staging and pathology?
# 4️⃣ What is the relationship between treatment response and recurrence?

# %% [markdown]
# ### IMPORT LIBRARIES

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from xgboost import XGBClassifier

# %%
# !pip install --upgrade plotly
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (6.0.1)
# Requirement already satisfied: narwhals>=1.15.1 in /usr/local/lib/python3.11/dist-packages (from plotly) (1.34.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly) (24.2)

# %% [markdown]
# ### READ DATAFRAME

# %%
# READ THE DATAFRAME
df = pd.read_csv('filtered_thyroid_data.csv')
df
# Out:
#      Age Gender Hx Radiothreapy Adenopathy       Pathology     Focality  Risk  \
# 0     27      F              No         No  Micropapillary    Uni-Focal   Low
# 1     34      F              No         No  Micropapillary    Uni-Focal   Low
# 2     30      F              No         No  Micropapillary    Uni-Focal   Low
# 3     62      F              No         No  Micropapillary    Uni-Focal   Low
# 4     62      F              No         No  Micropapillary  Multi-Focal   Low
# ..   ...    ...             ...        ...             ...          ...   ...
# 378   72      M             Yes      Right       Papillary    Uni-Focal  High
# 379   81      M             Yes  Extensive       Papillary  Multi-Focal  High
# 380   72      M              No  Bilateral       Papillary  Multi-Focal  High
# 381   61      M             Yes  Extensive    Hurthel cell  Multi-Focal  High
# 382   67      M              No  Bilateral       Papillary  Multi-Focal  High
#
#        T    N   M Stage                Response Recurred
# 0    T1a   N0  M0     I           Indeterminate       No
# 1    T1a   N0  M0     I               Excellent       No
# 2    T1a   N0  M0     I               Excellent       No
# 3    T1a   N0  M0     I               Excellent       No
# 4    T1a   N0  M0     I               Excellent       No
# ..   ...  ...  ..   ...                     ...      ...
# 378  T4b  N1b  M1   IVB  Biochemical Incomplete      Yes
# 379  T4b  N1b  M1   IVB   Structural Incomplete      Yes
# 380  T4b  N1b  M1   IVB   Structural Incomplete      Yes
# 381  T4b  N1b  M0   IVA   Structural Incomplete      Yes
# 382  T4b  N1b  M0   IVA   Structural Incomplete      Yes
#
# [383 rows x 13 columns]

# %% [markdown]
# ### EXPLORATORY DATA ANALYSIS

# %%
# DATASET INFO
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 383 entries, 0 to 382
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              383 non-null    int64
#  1   Gender           383 non-null    object
#  2   Hx Radiothreapy  383 non-null    object
#  3   Adenopathy       383 non-null    object
#  4   Pathology        383 non-null    object
#  5   Focality         383 non-null    object
#  6   Risk             383 non-null    object
#  7   T                383 non-null    object
#  8   N                383 non-null    object
#  9   M                383 non-null    object
#  10  Stage            383 non-null    object
#  11  Response         383 non-null    object
#  12  Recurred         383 non-null    object
# dtypes: int64(1), object(12)
# memory usage: 39.0+ KB

# %%
# UNIQUE VALUES OF CATEGORICAL FEATURES
df.select_dtypes(include='object').nunique().sort_values()
# Out:
# Gender             2
# Hx Radiothreapy    2
# Focality           2
# M                  2
# Recurred           2
# Risk               3
# N                  3
# Pathology          4
# Response           4
# Stage              5
# Adenopathy         6
# T                  7
# dtype: int64

# %%
# UNIQUE VALUES OF NUMERICAL FEATURE
df['Age'].nunique()
# Out:
# 65

# %%
# DEFINE CATEGORICAL FEATURES
categorical_features = df.select_dtypes(include=['object', 'category']).columns.tolist()
categorical_features
# Out:
# ['Gender',
#  'Hx Radiothreapy',
#  'Adenopathy',
#  'Pathology',
#  'Focality',
#  'Risk',
#  'T',
#  'N',
#  'M',
#  'Stage',
#  'Response',
#  'Recurred']

# %%
# DEFINE NUMERICAL FEATURES
numerical_features = df.select_dtypes(include='int64')
numerical_features
# Out:
#      Age
# 0     27
# 1     34
# 2     30
# 3     62
# 4     62
# ..   ...
# 378   72
# 379   81
# 380   72
# 381   61
# 382   67
#
# [383 rows x 1 columns]

# %%
# DISTRIBUTION OF CATEGORICAL FEATURES
for col in categorical_features:
    order = df[col].value_counts().index.tolist()
    fig = px.histogram(df, x=col, color=col,
                       title=f'DISTRIBUTION OF {col}',
                       category_orders={col: order})
    fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="b15af81c-dcb2-44dd-a479-fcd81f07935c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b15af81c-dcb2-44dd-a479-fcd81f07935c")) {                    Plotly.newPlot(                        "b15af81c-dcb2-44dd-a479-fcd81f07935c",                        [{"bingroup":"x","hovertemplate":"Gender=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"F","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"F","orientation":"v","showlegend":true,"x":["F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F"],"xaxis":"x","yaxis":"y","type":"histogram"},{"bingroup":"x","hovertemplate":"Gender=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"M","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"M","orientation":"v","showlegend":true,"x":["M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M"],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorb ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="1ce25913-4f42-4f46-b0db-2297acb6b64b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("1ce25913-4f42-4f46-b0db-2297acb6b64b")) {                    Plotly.newPlot(                        "1ce25913-4f42-4f46-b0db-2297acb6b64b",                        [{"bingroup":"x","hovertemplate":"Hx Radiothreapy=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","orientation":"v","showlegend":true,"x":["No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No"],"xaxis":"x","yaxis":"y","type":"histogram"},{"bingroup":"x","hovertemplate":"Hx Radiothreapy=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Yes","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Yes","orientation":"v","showlegend":true,"x":["Yes","Yes","Yes","Yes","Yes","Yes","Yes"],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"co ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="fab18f89-b450-481d-a654-2675af6a1f92" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("fab18f89-b450-481d-a654-2675af6a1f92")) {                    Plotly.newPlot(                        "fab18f89-b450-481d-a654-2675af6a1f92",                        [{"bingroup":"x","hovertemplate":"Adenopathy=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","orientation":"v","showlegend":true,"x":["No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No"],"xaxis":"x","yaxis":"y","type":"histogram"},{"bingroup":"x","hovertemplate":"Adenopathy=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Right","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Right","orientation":"v","showlegend":true,"x":["Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right"],"xaxis":"x","yaxis":"y","type":"histogram"},{"bingroup":"x","hovertemplate":"Adenopathy=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bilateral","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Bilateral","orientation":"v","showlegend":true,"x":["Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral"],"xaxis":"x","yaxis":"y","type":"histogram"},{"bingroup":"x","hovertemplate":"Adenopathy=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Left","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Left","orientation":"v","showlegend":true,"x":["Left","Left","Left","Left","Left","Left","Left","Left","Left","Left","Left","Left","Left","Left","Left","Left","Left"],"xaxis":"x","yaxis":"y","type":"histogram"},{"bingroup":"x","hovertemplate":" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="fef9a386-16a9-43ce-a550-815d27933a1d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("fef9a386-16a9-43ce-a550-815d27933a1d")) {                    Plotly.newPlot(                        "fef9a386-16a9-43ce-a550-815d27933a1d",                        [{"bingroup":"x","hovertemplate":"Pathology=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Papillary","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Papillary","orientation":"v","showlegend":true,"x":["Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papil ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="18d23c5f-0998-4b29-8442-384eae338dcd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("18d23c5f-0998-4b29-8442-384eae338dcd")) {                    Plotly.newPlot(                        "18d23c5f-0998-4b29-8442-384eae338dcd",                        [{"bingroup":"x","hovertemplate":"Focality=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Uni-Focal","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Uni-Focal","orientation":"v","showlegend":true,"x":["Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal"],"xaxis":"x","yaxis":"y","type":"histogram"},{"bingroup":"x","hovertemplate":"Focality=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Multi-Focal","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Mu ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="788aa584-8812-410a-84fa-b79c3e4bfeb3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("788aa584-8812-410a-84fa-b79c3e4bfeb3")) {                    Plotly.newPlot(                        "788aa584-8812-410a-84fa-b79c3e4bfeb3",                        [{"bingroup":"x","hovertemplate":"Risk=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Low","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Low","orientation":"v","showlegend":true,"x":["Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low"],"xaxis":"x","yaxis":"y","type":"histogram"},{"bingroup":"x","hovertemplate":"Risk=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Intermediate","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Intermediate","orientation":"v","showlegend":true,"x":["Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermedia ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="808f3515-181c-4767-b039-47421dabec78" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("808f3515-181c-4767-b039-47421dabec78")) {                    Plotly.newPlot(                        "808f3515-181c-4767-b039-47421dabec78",                        [{"bingroup":"x","hovertemplate":"T=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"T2","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"T2","orientation":"v","showlegend":true,"x":["T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2"],"xaxis":"x","yaxis":"y","type":"histogram"},{"bingroup":"x","hovertemplate":"T=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"T3a","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"T3a","orientation":"v","showlegend":true,"x":["T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a"],"xaxis":"x","yaxis":"y","type":"histogram"},{"bingroup":"x","hovertemplate":"T=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"T1a","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"T1a","orientation":"v","showlegend":true,"x":["T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a"],"xaxis":"x","yaxis":"y","type":"histogram"},{"bingroup":"x","hovertemplate":"T=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"T1b","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"T1b","orientation":"v","showlegend":true,"x":["T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b"],"xaxis":"x","yaxis":"y","type":"histogram"},{"bingroup":"x","hovertemplate":"T=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"T4a","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"T4a","orientation":"v","showlegend":true,"x":["T4a","T4a","T4a","T4a","T4a","T4a","T4a","T4a","T4a","T4a","T4a","T4a","T4a","T4a","T4a","T4a","T4a","T4a","T4a","T4a"],"xaxis":"x","yaxis":"y","type":"histogram"},{"bingroup":"x","hovertemplate":"T=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="2853e0bc-1d4a-4a3e-96ae-45e6b377922f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("2853e0bc-1d4a-4a3e-96ae-45e6b377922f")) {                    Plotly.newPlot(                        "2853e0bc-1d4a-4a3e-96ae-45e6b377922f",                        [{"bingroup":"x","hovertemplate":"N=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"N0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"N0","orientation":"v","showlegend":true,"x":["N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0"],"xaxis":"x","yaxis":"y","type":"histogram"},{"bingroup":"x","hovertemplate":"N=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"N1b","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"N1b","orientation":"v","showlegend":true,"x":["N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b"],"xaxis":"x","yaxis":"y","type":"histogram"},{"bingroup":"x","hovertemplate":"N=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"N1a","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"N1a","orientation":"v","showlegend":true,"x":["N1a","N1a","N1a","N1a","N1a","N1a","N1a","N1a","N1a","N1a","N1a","N1a","N1a","N1a","N1a","N1a","N1a","N1a","N1a","N1a","N1a","N1a"],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[ ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="19395474-5ff1-4e86-abd5-06f8be1f7063" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("19395474-5ff1-4e86-abd5-06f8be1f7063")) {                    Plotly.newPlot(                        "19395474-5ff1-4e86-abd5-06f8be1f7063",                        [{"bingroup":"x","hovertemplate":"M=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"M0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"M0","orientation":"v","showlegend":true,"x":["M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0"],"xaxis":"x","yaxis":"y","type":"histogram"},{"bingroup":"x","hovertemplate":"M=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"M1","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"M1","orientation":"v","showlegend":true,"x":["M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1"],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="42524414-6c56-4486-8977-a912d619a956" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("42524414-6c56-4486-8977-a912d619a956")) {                    Plotly.newPlot(                        "42524414-6c56-4486-8977-a912d619a956",                        [{"bingroup":"x","hovertemplate":"Stage=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"I","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"I","orientation":"v","showlegend":true,"x":["I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I"],"xaxis":"x","yaxis":"y","type":"histogram"},{"bingroup":"x","hovertemplate":"Stage=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"II","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"II","orientation":"v","showlegend":true,"x":["II","II","II","II","II","II","II","II","II","II","II","II","II","II","II","II","II","II","II","II","II","II","II","II","II","II","II","II","II","II","II","II"],"xaxis":"x","yaxis":"y","type":"histogram"},{"bingroup":"x","hovertemplate":"Stage=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"IVB","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"IVB","orientation":"v","showlegend":true,"x":["IVB","IVB","IVB","IVB","IVB","IVB","IVB","IVB","IVB","IVB","IVB"],"xaxis":"x","yaxis":"y","type":"histogram"},{"bingroup":"x","hovertemplate":"Stage=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"III","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"III","orientation":"v","showlegend":true,"x":["III","III","III","III"],"xaxis":"x","yaxis":"y","type":"histogram"},{"bingroup":"x","hovertemplate":"Stage=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"IVA","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"IVA","orientation":"v","showlegend":true,"x":["IVA","IVA","IVA"],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choroplet ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="fbce0804-bd4b-4193-aca1-60bed9e35652" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("fbce0804-bd4b-4193-aca1-60bed9e35652")) {                    Plotly.newPlot(                        "fbce0804-bd4b-4193-aca1-60bed9e35652",                        [{"bingroup":"x","hovertemplate":"Response=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Excellent","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Excellent","orientation":"v","showlegend":true,"x":["Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent"],"xaxis":"x","yaxis":"y","type":"histogram"},{"bingroup":"x","hovertemplate":"Response=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Structural Incomplete","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Structural Incomplete","orientation":"v","showlegend":true,"x":["Structural Incomplete","Structural Incomplete","Structural Incomplete","Structural Incomplete","Structural Incomplete","Structural Incomplete","Structural Incomplete","Structural Incomplete","Structural Incomplete","Structural Incomplete","Structural Incomplete","Structural Incomplete","Structural Incomplete","Structural Incomplete","Structural Incomplete","Structural Incomplete","Structural  ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="ae1bdc00-d60d-4bd5-8283-05cc829635bb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("ae1bdc00-d60d-4bd5-8283-05cc829635bb")) {                    Plotly.newPlot(                        "ae1bdc00-d60d-4bd5-8283-05cc829635bb",                        [{"bingroup":"x","hovertemplate":"Recurred=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","orientation":"v","showlegend":true,"x":["No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No"],"xaxis":"x","yaxis":"y","type":"histogram"},{"bingroup":"x","hovertemplate":"Recurred=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Yes","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Yes","orientation":"v","showlegend":true,"x":["Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes"],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0, ...

# %%
# DISTRIBUTION OF NUMERICAL FEATURES
for col in numerical_features:
    fig = px.histogram(df, x=col,
                       title=f'DISTRIBUTION OF {col}',
                       histfunc='count',
                       color_discrete_sequence=['skyblue'],
                       nbins=None,
                       )
    fig.update_layout(bargap=0.1)
    fig.update_traces(xbins=dict(
        start=df[col].min(),
        end=df[col].max(),
        size=1
    ))
    fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="4acac743-d68f-48cb-ba17-f3f2307e46a7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("4acac743-d68f-48cb-ba17-f3f2307e46a7")) {                    Plotly.newPlot(                        "4acac743-d68f-48cb-ba17-f3f2307e46a7",                        [{"bingroup":"x","histfunc":"count","hovertemplate":"Age=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"skyblue","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"x":{"dtype":"i1","bdata":"GyIePj40KS4zKEs7MTJMKigsKzQpLCRGPCErGiklJR4kNzQlHysoIjMtFCYmIR8fGh0rHhkbGRUrFxcrGCM2NhYmIzMWMyhFHx0eHBYdIzIbERsoIRlJJCMfEj4+JyUaHxg5HCwqGzMhKhoYPDwfQiwgGiUhFy8cJRocHCwfGzg\"},"xaxis":"x","yaxis":"y","type":"histogram","xbins":{"end":82,"size":1,"start":15}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0 ...

# %%
# RISK LEVEL vs AGE
# NUMBER OF PATIENTS vs RISK LEVEL
fig = px.box(df,
             x='Risk',
             y='Age',
             color='Risk',
             points='all',
             title='RISK LEVEL BY AGE')
fig.show()

risk_counts = df['Risk'].value_counts().reset_index()
risk_counts.columns = ['Risk Level', 'Count']

fig = px.bar(risk_counts,
             x='Risk Level',
             y='Count',
             text='Count',
             color='Risk Level',
             title='NUMBER OF PATIENTS BY RISK LEVEL')

fig.update_traces(textposition='outside')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="236e1260-beff-49fb-9d49-0648688d5014" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("236e1260-beff-49fb-9d49-0648688d5014")) {                    Plotly.newPlot(                        "236e1260-beff-49fb-9d49-0648688d5014",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"Risk=%{x}\u003cbr\u003eAge=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Low","marker":{"color":"#636efa"},"name":"Low","notched":false,"offsetgroup":"Low","orientation":"v","showlegend":true,"x":["Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low"],"x0":" ","xaxis":"x","y":{"dtype":"i1","bdata":"GyIePj40KS4zKEs7MTJMKigsKzQpLCRGPCErGiklJR4kNzQlHysoIjMtFCYmIR0rHhkbGRUrFxcrGCM2NhYmIzMWMyhFHx0eHBYdIzIbERsZSSQ+JyUaHxg5HCwqGzMhKhoYPDwfQiwgGiUhFy8cJRocHCwfGzg\u002fGB4fIBwzFBUgGiocKSoxHR0ZKSEbMhMjPxgkHxghGBwWGxwdKB83FSgmFR8eMiItNCZDSC0tGkM4HiIyKiMXLBcaPRYfRDkbGSEkJB8hHCgdIzgUPhUdIT44NCMgGzQuHiAZJh8lFSIeMB80JikpRhMpICMnLS4tHB9RFR0zKiI4"},"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"Risk=%{x}\u003cbr\u003eAge=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Intermediate","marker":{"color":"#EF553B"},"name":"Intermediate","notched":false,"offsetgroup":"Intermediate","orientation":"v","showlegend":true,"x":["Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediat ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="541d9ca9-6f0a-4d40-8894-1a53d6635fcc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("541d9ca9-6f0a-4d40-8894-1a53d6635fcc")) {                    Plotly.newPlot(                        "541d9ca9-6f0a-4d40-8894-1a53d6635fcc",                        [{"hovertemplate":"Risk Level=%{x}\u003cbr\u003eCount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Low","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Low","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAgb0A="},"textposition":"outside","x":["Low"],"xaxis":"x","y":{"dtype":"i2","bdata":"+QA="},"yaxis":"y","type":"bar"},{"hovertemplate":"Risk Level=%{x}\u003cbr\u003eCount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Intermediate","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Intermediate","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAACAWUA="},"textposition":"outside","x":["Intermediate"],"xaxis":"x","y":{"dtype":"i1","bdata":"Zg=="},"yaxis":"y","type":"bar"},{"hovertemplate":"Risk Level=%{x}\u003cbr\u003eCount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"High","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"High","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAAQEA="},"textposition":"outside","x":["High"],"xaxis":"x","y":{"dtype":"i1","bdata":"IA=="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewid ...

# %%
# RECURRENCE vs STAGE
stage_order = ['I', 'II', 'III', 'IVA', 'IVB']
df['Stage'] = pd.Categorical(df['Stage'], categories=stage_order, ordered=True)

prop_df = df.groupby('Stage')['Recurred'].value_counts(normalize=True).rename('Proportion').reset_index()

fig = px.bar(prop_df,
             x='Stage',
             y='Proportion',
             color='Recurred',
             barmode='stack',
             text=prop_df['Proportion'].round(2),
             title='RECURRENCE RATIO BY STAGE')
fig.update_traces(textposition='inside')
fig.show()


fig = px.histogram(df,
                   x='Stage',
                   color='Recurred',
                   barmode='group',
                   text_auto=True,
                   title='RECURRENCE COUNT BY STAGE')
fig.show()
# Out:
# <ipython-input-15-1cfe93deed6c>:5: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="fd8ae691-6d55-445d-a9d2-742c263c9455" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("fd8ae691-6d55-445d-a9d2-742c263c9455")) {                    Plotly.newPlot(                        "fd8ae691-6d55-445d-a9d2-742c263c9455",                        [{"hovertemplate":"Recurred=No\u003cbr\u003eStage=%{x}\u003cbr\u003eProportion=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZ6T8pXI\u002fC9SjMPwAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA=="},"textposition":"inside","x":["I","II","III","IVA","IVB"],"xaxis":"x","y":{"dtype":"f8","bdata":"D5yJAfbA6T8AAAAAAADMPwAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA=="},"yaxis":"y","type":"bar"},{"hovertemplate":"Recurred=Yes\u003cbr\u003eStage=%{x}\u003cbr\u003eProportion=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Yes","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Yes","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZyT\u002f2KFyPwvXoPwAAAAAAAPA\u002fAAAAAAAA8D8AAAAAAADwPw=="},"textposition":"inside","x":["I","II","III","IVA","IVB"],"xaxis":"x","y":{"dtype":"f8","bdata":"wo\u002fZ+Sf8yD8AAAAAAADpPwAAAAAAAPA\u002fAAAAAAAA8D8AAAAAAADwPw=="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatter ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="1ea24bcd-42d4-41e2-a2c0-d51d363e97ba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("1ea24bcd-42d4-41e2-a2c0-d51d363e97ba")) {                    Plotly.newPlot(                        "1ea24bcd-42d4-41e2-a2c0-d51d363e97ba",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Recurred=No\u003cbr\u003eStage=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","II","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","II","I","I","I","I","I","I","I","I","II","II","II","I","I","I","I","I","I","I","II","I","II","I","I","I"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Recurred=Yes\u003cbr\u003eStage=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Yes","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Yes","offsetgroup":"Yes","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","II","II","I","I","I","IVB","I","I","I","I","II","II","II","II","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","II","II","II","II","II","II","I","II","I","I","I","I","I","II","I","I","I","I","II","I","I","I","I","I","I","II","II","III","II","I","I","IVB","II","II","I","I","I","I","I","III","III","IVB","IVB","IVB","II","II","III","IVB","II","IVA","II","IVB","IVB","I","II","IVB","IVB","IVB","IVA","IVA"],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[ ...

# %%
# RECURRENCE vs PATHOLOGY
prop_df = df.groupby('Pathology')['Recurred'].value_counts(normalize=True).rename('Proportion').reset_index()
fig = px.bar(prop_df,
             x='Pathology',
             y='Proportion',
             color='Recurred',
             barmode='stack',
             text=prop_df['Proportion'].round(2),
             title='RECURRENCE RATIO BY PATHOLOGY')
fig.update_traces(textposition='inside')
fig.show()

fig = px.histogram(df,
                   x='Pathology',
                   color='Recurred',
                   barmode='group',
                   text_auto=True,
                   title='RECURRENCE COUNT BY PATHOLOGY')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="33863876-dc42-4d29-9878-6024f7ec4fb2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("33863876-dc42-4d29-9878-6024f7ec4fb2")) {                    Plotly.newPlot(                        "33863876-dc42-4d29-9878-6024f7ec4fb2",                        [{"hovertemplate":"Recurred=No\u003cbr\u003ePathology=%{x}\u003cbr\u003eProportion=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"PQrXo3A94j9mZmZmZmbmPwAAAAAAAPA\u002fFK5H4XoU5j8="},"textposition":"inside","x":["Follicular","Hurthel cell","Micropapillary","Papillary"],"xaxis":"x","y":{"dtype":"f8","bdata":"kiRJkiRJ4j9mZmZmZmbmPwAAAAAAAPA\u002fZZEDhBT35T8="},"yaxis":"y","type":"bar"},{"hovertemplate":"Recurred=Yes\u003cbr\u003ePathology=%{x}\u003cbr\u003eProportion=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Yes","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Yes","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"hetRuB6F2z8zMzMzMzPTP9ejcD0K19M\u002f"},"textposition":"inside","x":["Follicular","Hurthel cell","Papillary"],"xaxis":"x","y":{"dtype":"f8","bdata":"27Zt27Zt2z8zMzMzMzPTPzbd+PfWEdQ\u002f"},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorb ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="328822c6-6303-41f8-810c-217536882e93" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("328822c6-6303-41f8-810c-217536882e93")) {                    Plotly.newPlot(                        "328822c6-6303-41f8-810c-217536882e93",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Recurred=No\u003cbr\u003ePathology=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Papillary","Follicular","Micropapillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Hurthel cell","Hurthel cell","Hurthel cell","Hurthel cell","Hurthel cell","Follicular","Follicular","Follicular","Follicular","Follicular","Follicular","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Follicular","Papillary","Papillary","Hurthel cell","Hurthel cell","Hurthel cell","Hurthel cell","Follicular","Follicular","Follicular","Follicular","Follicular","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papil ...

# %%
# RECURRENCE vs RESPONSE
prop_df = df.groupby('Response')['Recurred'].value_counts(normalize=True).rename('Proportion').reset_index()
fig = px.bar(prop_df,
             x='Response',
             y='Proportion',
             color='Recurred',
             barmode='stack',
             text=prop_df['Proportion'].round(2),
             title='RECURRENCE RATIO BY RESPONSE')
fig.update_traces(textposition='inside')
fig.show()

fig = px.histogram(df,
                   x='Response',
                   color='Recurred',
                   barmode='group',
                   text_auto=True,
                   title='RECURRENCE COUNT BY RESPONSE')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="86dfaafb-701d-4120-8021-76ab48d0f761" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("86dfaafb-701d-4120-8021-76ab48d0f761")) {                    Plotly.newPlot(                        "86dfaafb-701d-4120-8021-76ab48d0f761",                        [{"hovertemplate":"Recurred=No\u003cbr\u003eResponse=%{x}\u003cbr\u003eProportion=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"pHA9Ctej4D8AAAAAAADwP3sUrkfheuw\u002fexSuR+F6lD8="},"textposition":"inside","x":["Biochemical Incomplete","Excellent","Indeterminate","Structural Incomplete"],"xaxis":"x","y":{"dtype":"f8","bdata":"C1nIQhay4D+KndiJndjvP0OwjjbvU+w\u002fF2iBFmiBlj8="},"yaxis":"y","type":"bar"},{"hovertemplate":"Recurred=Yes\u003cbr\u003eResponse=%{x}\u003cbr\u003eProportion=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Yes","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Yes","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"uB6F61G43j8AAAAAAAAAAClcj8L1KLw\u002fXI\u002fC9Shc7z8="},"textposition":"inside","x":["Biochemical Incomplete","Excellent","Indeterminate","Structural Incomplete"],"xaxis":"x","y":{"dtype":"f8","bdata":"6k1vetOb3j8UO7ETO7FzP+d9ikuGYL0\u002fv\u002fRLv\u002fRL7z8="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="d5cdc41e-da95-47f2-9995-e9436acdd86f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d5cdc41e-da95-47f2-9995-e9436acdd86f")) {                    Plotly.newPlot(                        "d5cdc41e-da95-47f2-9995-e9436acdd86f",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Recurred=No\u003cbr\u003eResponse=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Indeterminate","Excellent","Excellent","Excellent","Excellent","Indeterminate","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Indeterminate","Excellent","Indeterminate","Excellent","Indeterminate","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Indeterminate","Excellent","Excellent","Excellent","Indeterminate","Excellent","Excellent","Excellent","Indeterminate","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Indeterminate","Excellent","Excellent","Excellent","Indeterminate","Excellent","Excellent","Indeterminate","Excellent","Excellent","Excellent","Excellent","Indeterminate","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Biochemical Incomplete","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Indeterminate","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Biochemical Incomplete","Excellent","Biochemical Incomplete","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Biochemical Incomplete","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Indeterminate","Indeterminate","Excellent","Excellent","Excellent","Excellent","Excellent","Biochemical Incomplete","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Indeterminate","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Indeterminate","Indeterminate","Excellent","Excellent","Excellent","Excellent","Excellent","Indeterminate","Excellent","Biochemical Incomplete","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Indeterminate","Indeterminate","Indeterminate","Excellent","Excellent","Excellent","Indeterminate","Indeterminate","Indeterminate","Indeterminate","Excellent","Indeterminate","Indeterminate","Indeterminate","Excellent","Indeterminate","Excellent","Indeterminate","Biochemical Incomplete","Excellent","Indeterminate","Excellent","Excellent","Structural Incomplete","Excellent","Excellent","Indeterminate","Excellent","Biochemical Incomplete","Indeterminate","Excellent","Biochemical Incomplete","Excellent","Biochemical Incomplete","Indeterminate","Excellent","Indeterminate","Excellent"," ...

# %% [markdown]
# ### FEATURE ENGINEERING

# %%
# LABEL ENCODING
le = LabelEncoder()
for col in df.select_dtypes(include=['object', 'category']).columns:
    df[col] = le.fit_transform(df[col])

# %%
df.head()
# Out:
#    Age  Gender  Hx Radiothreapy  Adenopathy  Pathology  Focality  Risk  T  N  \
# 0   27       0                0           3          2         1     2  0  0
# 1   34       0                0           3          2         1     2  0  0
# 2   30       0                0           3          2         1     2  0  0
# 3   62       0                0           3          2         1     2  0  0
# 4   62       0                0           3          2         0     2  0  0
#
#    M  Stage  Response  Recurred
# 0  0      0         2         0
# 1  0      0         1         0
# 2  0      0         1         0
# 3  0      0         1         0
# 4  0      0         1         0

# %%
correlation_matrix = df.corr()

# %%
# CORRELATION MATRIX
fig = px.imshow(
    correlation_matrix,
    text_auto=".2f",
    color_continuous_scale="RdBu",
    title="CORRELATION MATRIX"
)

fig.update_layout(
    width=1000,
    height=800,
    margin=dict(l=50, r=50, t=50, b=50)
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="515cfad4-7715-42d9-b572-9cf9d3792683" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("515cfad4-7715-42d9-b572-9cf9d3792683")) {                    Plotly.newPlot(                        "515cfad4-7715-42d9-b572-9cf9d3792683",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z:.2f}","x":["Age","Gender","Hx Radiothreapy","Adenopathy","Pathology","Focality","Risk","T","N","M","Stage","Response","Recurred"],"y":["Age","Gender","Hx Radiothreapy","Adenopathy","Pathology","Focality","Risk","T","N","M","Stage","Response","Recurred"],"z":{"dtype":"f8","bdata":"AAAAAAAA8D\u002fQ5SMq0N3HPx4pvONymsY\u002fKMaAxXf8ub+U61c7rXDEv\u002f\u002fm1tAAp8y\u002feomXt2Hq0r+YPOt+zA\u002fPPxzW2t5DW68\u002fvqqox5shzj816WV1DtzgP+Pl+PRRH8c\u002fUa62xMSR0D\u002fQ5SMq0N3HPwAAAAAAAPA\u002f5VGkqdYwzj+fWJYPWqTLv6OrCDCZGpi\u002fLCaeucGTyr8LnronCuXSv9Yohy6bZ9E\u002fFRBmPuCPzj+k4mcbuhPLPxslFa2GA9A\u002fdkyyuax20T+RI6UVDQHVPx4pvONymsY\u002f5VGkqdYwzj8AAAAAAADwP1Sqfflzla2\u002fHkpMSo5Bu79rSM3f5Te6vwdQ+95badG\u002foGNJG8\u002fmzD\u002fw6SIn83S4P1gAaQahiNs\u002fDBf+wsiP3T\u002ftceTj0By7P9Y3bZT1UsY\u002fKMaAxXf8ub+fWJYPWqTLv1Sqfflzla2\u002fAAAAAAAA8D\u002fUg+ubsfKOv1xMVShkfsY\u002fv7SxUV9Nxz\u002fJKy\u002f9OJTKv0BZIL92v8O\u002fW9dmKAibtL+FcvtEdTXDv22G3slkaMi\u002fuG+zIyhdx7+U61c7rXDEv6OrCDCZGpi\u002fHkpMSo5Bu7\u002fUg+ubsfKOvwAAAAAAAPA\u002f16rAA63xnj+X8yJfzNaUP6VbXW6nJn8\u002f9E4MMpPlzj+N6NsPvZG4vzjBqJqwdby\u002feoStCU5ZlL+gqotcTM1qP\u002f\u002fm1tAAp8y\u002fLCaeucGTyr9rSM3f5Te6v1xMVShkfsY\u002f16rAA63xnj8AAAAAAADwP38\u002ftjji1tw\u002fpPC3HfYb3b9OB\u002f6kuRvYv3NBMbY9aMy\u002fDVkTQ7k91b\u002fxyEEdPNHWv1G4eV7Kj9i\u002feomXt2Hq0r8LnronCuXSvwdQ+95badG\u002fv7SxUV9Nxz+X8yJfzNaUP38\u002ftjji1tw\u002fAAAAAAAA8D8\u002fyGoWp8Tlv2pht\u002fPkS+a\u002f71MiDsAZ4L9ErthbPtLjv02Wh43vZOO\u002fZex2rNB357+YPOt+zA\u002fPP9Yohy6bZ9E\u002foGNJG8\u002fmzD\u002fJKy\u002f9OJTKv6VbXW6nJn8\u002fpPC3HfYb3b8\u002fyGoWp8TlvwAAAAAAAPA\u002fM2bgw1lb3T+xguGGA93YP3VphGXTOeE\u002fe5mQKQpq3T+Bfvw1ZszhPxzW2t5DW68\u002fFRBmPuCPzj\u002fw6SIn83S4P0BZIL92v8O\u002f9E4MMpPlzj9OB\u002f6kuRvYv2pht\u002fPkS+a\u002fM2bgw1lb3T8AAAAAAADwP6aDEAEDEcw\u002fBC0eu9GN0T\u002fAw49kkK7iP0UXLnL+O+Q\u002fvqqox5shzj+k4mcbuhPLP1gAaQahiNs\u002fW9dmKAibtL+N6NsPvZG4v3NBMbY9aMy\u002f71MiDsAZ4L+xguGGA93YP6aDEAEDEcw\u002fAAAAAAAA8D+4QCzl6MrlP0VpHtFihtM\u002fwMQ5L9St1j816WV1DtzgPxslFa2GA9A\u002fDBf+wsiP3T+FcvtEdTXDvzjBqJqwdby\u002fDVkTQ7k91b9ErthbPtLjv3VphGXTOeE\u002fBC0eu9GN0T+4QCzl6MrlPwAAAAAAAPA\u002fQk5X976f1T9+Yj9vqr7cP+Pl+PRRH8c\u002fdkyyuax20T\u002ftceTj0By7P22G3slkaMi\u002feoStCU5ZlL\u002fxyEEdPNHWv02Wh43vZOO\u002fe5mQKQpq3T\u002fAw49kkK7iP0VpHtFihtM\u002fQk5X976f1T8AAAAAAADwP6Z0WMbFr+Y\u002fUa62xMSR0D+RI6UVDQHVP9Y3bZT1UsY\u002fuG+zIyhdx7+gqotcTM1qP1G4eV7Kj9i\u002fZex2rNB357+Bfvw1ZszhP0UXLnL+O+Q\u002fwMQ5L9St1j9+Yj9vqr7cP6Z0WMbFr+Y\u002fAAAAAAAA8D8=","shape":"13, 13"},"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}\u003cbr\u003ey: %{y}\u003cbr\u003ecolor: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333," ...

# %%
# CORRELATION VALUES
corr = df.corr(numeric_only=True)
print(corr['Recurred'].sort_values(ascending=False))
# Out:
# Recurred           1.000000
# Response           0.708957
# N                  0.632323
# T                  0.556201
# Stage              0.449137
# M                  0.354360
# Gender             0.328189
# Age                0.258897
# Hx Radiothreapy    0.174407
# Pathology          0.003272
# Adenopathy        -0.182530
# Focality          -0.383776
# Risk              -0.733376
# Name: Recurred, dtype: float64

# %%
# DEFINE FEATURES AND TARGET
X = df.drop(['Recurred', 'Risk', 'Response'], axis=1)
y = df['Recurred']

# %%
# FEATURE SCALING
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# SPLIT DATASET
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, stratify=y, random_state=42)

# %% [markdown]
# ### APPLICATION OF MACHINE LEARNING MODELS

# %%
# LOGISTIC REGRESSION MODEL
lr = LogisticRegression()
lr.fit(X_train, y_train)
predict_lr = lr.predict(X_test)
print("Logistic Regression Report:\n", classification_report(y_test, predict_lr))
# Out:
# Logistic Regression Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.91      0.93        55
#            1       0.80      0.91      0.85        22
#
#     accuracy                           0.91        77
#    macro avg       0.88      0.91      0.89        77
# weighted avg       0.92      0.91      0.91        77

# %%
# RANDOM FOREST CLASSIFIER MODEL
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
predict_rf = rf.predict(X_test)
print("Random Forest Report:\n", classification_report(y_test, predict_rf))
# Out:
# Random Forest Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91        55
#            1       0.77      0.77      0.77        22
#
#     accuracy                           0.87        77
#    macro avg       0.84      0.84      0.84        77
# weighted avg       0.87      0.87      0.87        77

# %%
# XGBOOST MODEL
xgb = XGBClassifier(use_label_encoder=False, eval_metric='logloss')
xgb.fit(X_train, y_train)
predict_xgb = xgb.predict(X_test)
print("XGBoost Report:\n", classification_report(y_test, predict_xgb))
# Out:
# XGBoost Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.89      0.91        55
#            1       0.75      0.82      0.78        22
#
#     accuracy                           0.87        77
#    macro avg       0.84      0.85      0.85        77
# weighted avg       0.87      0.87      0.87        77
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning:
#
# [14:43:34] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.

# %% [markdown]
# ### MODEL EVALUATION

# %%
# METRICS BY MODEL
reports = []

report_lr = classification_report(y_test, predict_lr, output_dict=True)
acc_lr = accuracy_score(y_test, predict_lr)
reports.append({'Model': 'Logistic Regression',
                'Precision': report_lr['macro avg']['precision'],
                'Recall': report_lr['macro avg']['recall'],
                'F1-Score': report_lr['macro avg']['f1-score'],
                'Accuracy': acc_lr})

report_rf = classification_report(y_test, predict_rf, output_dict=True)
acc_rf = accuracy_score(y_test, predict_rf)
reports.append({'Model': 'Random Forest',
                'Precision': report_rf['macro avg']['precision'],
                'Recall': report_rf['macro avg']['recall'],
                'F1-Score': report_rf['macro avg']['f1-score'],
                'Accuracy': acc_rf})

report_xgb = classification_report(y_test, predict_xgb, output_dict=True)
acc_xgb = accuracy_score(y_test, predict_xgb)
reports.append({'Model': 'XGBoost',
                'Precision': report_xgb['macro avg']['precision'],
                'Recall': report_xgb['macro avg']['recall'],
                'F1-Score': report_xgb['macro avg']['f1-score'],
                'Accuracy': acc_xgb})

df_metrics = pd.DataFrame(reports)

df_melted = df_metrics.melt(id_vars='Model', var_name='Metric', value_name='Score')

fig = px.bar(df_melted, x='Model', y='Score', color='Metric', barmode='group',
             text_auto='.2f', title='Model Comparison: Accuracy, Precision, Recall & F1-score (Macro Avg)')
fig.update_layout(yaxis=dict(range=[0.8, 1.05]))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="697615be-07bb-4b62-be29-e4fa61cec09f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("697615be-07bb-4b62-be29-e4fa61cec09f")) {                    Plotly.newPlot(                        "697615be-07bb-4b62-be29-e4fa61cec09f",                        [{"alignmentgroup":"True","hovertemplate":"Metric=Precision\u003cbr\u003eModel=%{x}\u003cbr\u003eScore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Precision","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Precision","offsetgroup":"Precision","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.2f}","x":["Logistic Regression","Random Forest","XGBoost"],"xaxis":"x","y":{"dtype":"f8","bdata":"9EIv9EIv7D\u002fooosuuujqP3RITTDeyuo\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Metric=Recall\u003cbr\u003eModel=%{x}\u003cbr\u003eScore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Recall","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Recall","offsetgroup":"Recall","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.2f}","x":["Logistic Regression","Random Forest","XGBoost"],"xaxis":"x","y":{"dtype":"f8","bdata":"F1100UUX7T\u002fooosuuujqP1j7hrVvWOs\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Metric=F1-Score\u003cbr\u003eModel=%{x}\u003cbr\u003eScore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"F1-Score","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"F1-Score","offsetgroup":"F1-Score","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.2f}","x":["Logistic Regression","Random Forest","XGBoost"],"xaxis":"x","y":{"dtype":"f8","bdata":"TI8trf6R7D\u002fooosuuujqPxSrRVNOCus\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Metric=Accuracy\u003cbr\u003eModel=%{x}\u003cbr\u003eScore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Accuracy","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Accuracy","offsetgroup":"Accuracy","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.2f}","x":["Logistic Regression","Random Forest","XGBoost"],"xaxis":"x","y":{"dtype":"f8","bdata":"F1100UUX7T9qYO+YGtjrP2pg75ga2Os\u002f"},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""}," ...

# %% [markdown]
# ### FINAL ANALYSIS, INSIGHTS AND CONCLUSION

# %% [markdown]
# ## 🔍 Final Analysis and Key Findings
#
# ### 1. Are thyroid cancer recurrences more common in men or women?
# While most patients in the dataset are women, **men show a higher proportion of recurrence**. This suggests that male patients may be at increased risk and deserve closer monitoring.
#
# ### 2. How does age affect recurrence risk?
# There is a **moderate positive correlation (0.26)** between age and recurrence. Older patients tend to experience recurrence more frequently, although age alone is not the most dominant factor.
#
# ### 3. Can recurrence be predicted based on tumor staging and pathology?
# Yes. Variables such as **Stage, T, N, M, and Pathology** all show relevant patterns:
# - Recurrence rates increase with higher cancer stages (Stage IV).
# - Some pathology types like **Papillary** and **Hurthel cell** are more frequently associated with recurrence.
# - These patterns were confirmed by predictive models using these features.
#
# ### 4. What is the relationship between treatment response and recurrence?
# A very clear one: patients with **“Structural Incomplete”** or **“Biochemical Incomplete”** responses have significantly higher recurrence rates, while those with an **“Excellent”** response rarely relapse. `Response` shows the **strongest correlation (0.71)** with recurrence.
#
# ## 📊 Key Insights
# - `Risk` classification shows the **strongest negative correlation (-0.73)** with recurrence. Higher-risk patients are much more likely to relapse.
# - **Logistic Regression** delivered the best balance between precision and recall.
# - **XGBoost** performed more balanced across both classes (recurred / not recurred), while **Random Forest** performed slightly better for non-recurrences.
#
# ## ✅ Overall Conclusion
#
# The results confirm that it is possible to accurately predict thyroid cancer recurrence using clinical data. Key variables like **tumor stage, treatment response, and risk** allow for early identification of high-risk patients. These models could support clinical decision-making and personalized follow-up strategies.
#
# **Author:** Adrian Zambrana · April 2025
