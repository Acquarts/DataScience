# %% [markdown]
# ## THYROID CANCER RECURRENCE | Predictive and Analytic Model

# %% [markdown]
# # Thyroid Cancer Recurrence Prediction
#
# This project analyzes clinical data from thyroid cancer patients to predict recurrence after radioactive iodine (RAI) therapy. It explores patterns, answers key clinical questions, and trains machine learning models for predictive purposes.
#
# ## 📁 About the Dataset
#
# This dataset focuses on thyroid cancer recurrence after Radioactive Iodine (RAI) therapy. It contains 383 patient records with 13 key attributes, including age, gender, cancer staging, pathology type, risk classification, treatment response, and recurrence status. The data is valuable for predicting cancer recurrence, understanding risk factors, and evaluating treatment outcomes.
#
# ### 📊 Dataset Overview
# - 📌 Total Rows: 383
# - 📌 Total Columns: 13
# - 📌 No Missing Values
#
# ### 🔹 Column Descriptions
# - **Age**: Age of the patient (in years)
# - **Gender**: Patient's gender (Male or Female)
# - **Hx Radiotherapy**: History of prior radiotherapy (Yes or No)
# - **Adenopathy**: Presence of lymph node involvement (Yes or No)
# - **Pathology**: Type of thyroid cancer (e.g., Micropapillary)
# - **Focality**: Tumor focality (Uni-Focal or Multi-Focal)
# - **Risk**: Cancer risk classification (Low, Intermediate, High)
# - **T**: Tumor classification (T1, T2, etc.)
# - **N**: Lymph node classification (N0, N1, etc.)
# - **M**: Metastasis classification (M0, M1, etc.)
# - **Stage**: Cancer staging (Stage I, II, III, IV)
# - **Response**: Treatment response (Excellent, Indeterminate, etc.)
# - **Recurred**: Whether cancer recurred (Yes or No)
#
# ## ❓ Key Questions to Explore
#
# 1️⃣ Are thyroid cancer recurrences more common in men or women?
# 2️⃣ How does age affect recurrence risk?
# 3️⃣ Can we predict recurrence based on tumor staging and pathology?
# 4️⃣ What is the relationship between treatment response and recurrence?

# %% [markdown]
# ### IMPORT LIBRARIES

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from xgboost import XGBClassifier

# %% [markdown]
# ### READ DATAFRAME

# %%
# READ THE DATAFRAME
df = pd.read_csv('filtered_thyroid_data.csv')
df
# Out:
#      Age Gender Hx Radiothreapy Adenopathy       Pathology     Focality  Risk  \
# 0     27      F              No         No  Micropapillary    Uni-Focal   Low
# 1     34      F              No         No  Micropapillary    Uni-Focal   Low
# 2     30      F              No         No  Micropapillary    Uni-Focal   Low
# 3     62      F              No         No  Micropapillary    Uni-Focal   Low
# 4     62      F              No         No  Micropapillary  Multi-Focal   Low
# ..   ...    ...             ...        ...             ...          ...   ...
# 378   72      M             Yes      Right       Papillary    Uni-Focal  High
# 379   81      M             Yes  Extensive       Papillary  Multi-Focal  High
# 380   72      M              No  Bilateral       Papillary  Multi-Focal  High
# 381   61      M             Yes  Extensive    Hurthel cell  Multi-Focal  High
# 382   67      M              No  Bilateral       Papillary  Multi-Focal  High
#
#        T    N   M Stage                Response Recurred
# 0    T1a   N0  M0     I           Indeterminate       No
# 1    T1a   N0  M0     I               Excellent       No
# 2    T1a   N0  M0     I               Excellent       No
# 3    T1a   N0  M0     I               Excellent       No
# 4    T1a   N0  M0     I               Excellent       No
# ..   ...  ...  ..   ...                     ...      ...
# 378  T4b  N1b  M1   IVB  Biochemical Incomplete      Yes
# 379  T4b  N1b  M1   IVB   Structural Incomplete      Yes
# 380  T4b  N1b  M1   IVB   Structural Incomplete      Yes
# 381  T4b  N1b  M0   IVA   Structural Incomplete      Yes
# 382  T4b  N1b  M0   IVA   Structural Incomplete      Yes
#
# [383 rows x 13 columns]

# %% [markdown]
# ### EXPLORATORY DATA ANALYSIS

# %%
# DATASET INFO
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 383 entries, 0 to 382
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              383 non-null    int64
#  1   Gender           383 non-null    object
#  2   Hx Radiothreapy  383 non-null    object
#  3   Adenopathy       383 non-null    object
#  4   Pathology        383 non-null    object
#  5   Focality         383 non-null    object
#  6   Risk             383 non-null    object
#  7   T                383 non-null    object
#  8   N                383 non-null    object
#  9   M                383 non-null    object
#  10  Stage            383 non-null    object
#  11  Response         383 non-null    object
#  12  Recurred         383 non-null    object
# dtypes: int64(1), object(12)
# memory usage: 39.0+ KB

# %%
# UNIQUE VALUES OF CATEGORICAL FEATURES
df.select_dtypes(include='object').nunique().sort_values()
# Out:
# Gender             2
# Hx Radiothreapy    2
# Focality           2
# M                  2
# Recurred           2
# Risk               3
# N                  3
# Pathology          4
# Response           4
# Stage              5
# Adenopathy         6
# T                  7
# dtype: int64

# %%
# UNIQUE VALUES OF NUMERICAL FEATURE
df['Age'].nunique()
# Out:
# 65

# %%
# DEFINE CATEGORICAL FEATURES
categorical_features = df.select_dtypes(include=['object', 'category']).columns.tolist()
categorical_features
# Out:
# ['Gender',
#  'Hx Radiothreapy',
#  'Adenopathy',
#  'Pathology',
#  'Focality',
#  'Risk',
#  'T',
#  'N',
#  'M',
#  'Stage',
#  'Response',
#  'Recurred']

# %%
# DEFINE NUMERICAL FEATURES
numerical_features = df.select_dtypes(include='int64')
numerical_features
# Out:
#      Age
# 0     27
# 1     34
# 2     30
# 3     62
# 4     62
# ..   ...
# 378   72
# 379   81
# 380   72
# 381   61
# 382   67
#
# [383 rows x 1 columns]

# %%
# DISTRIBUTION OF CATEGORICAL FEATURES
for col in categorical_features:
    order = df[col].value_counts().index.tolist()
    fig = px.histogram(df, x=col, color=col,
                       title=f'DISTRIBUTION OF {col}',
                       category_orders={col: order})
    fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3102aacb-c17f-45dd-be02-3a486c3c8809" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3102aacb-c17f-45dd-be02-3a486c3c8809")) {                    Plotly.newPlot(                        "3102aacb-c17f-45dd-be02-3a486c3c8809",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Gender=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"F","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"F","offsetgroup":"F","orientation":"v","showlegend":true,"x":["F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Gender=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"M","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"M","offsetgroup":"M","orientation":"v","showlegend":true,"x":["M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M"],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a7768b78-eb60-4755-b20d-fa4a2cca49ee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a7768b78-eb60-4755-b20d-fa4a2cca49ee")) {                    Plotly.newPlot(                        "a7768b78-eb60-4755-b20d-fa4a2cca49ee",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Hx Radiothreapy=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"x":["No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Hx Radiothreapy=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Yes","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Yes","offsetgroup":"Yes","orientation":"v","showlegend":true,"x":["Yes","Yes","Yes","Yes","Yes","Yes","Yes"],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.88888888 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0c570f29-23da-4930-b8b6-973de07b7803" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0c570f29-23da-4930-b8b6-973de07b7803")) {                    Plotly.newPlot(                        "0c570f29-23da-4930-b8b6-973de07b7803",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Adenopathy=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"x":["No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Adenopathy=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Right","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Right","offsetgroup":"Right","orientation":"v","showlegend":true,"x":["Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right","Right"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Adenopathy=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bilateral","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Bilateral","offsetgroup":"Bilateral","orientation":"v","showlegend":true,"x":["Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral","Bilateral"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Adenopathy=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Left","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Left","offsetgroup":"Left","orientation":"v","showlegend ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e9c58b1e-11fe-4f3a-a6d1-e4fa00dc229a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e9c58b1e-11fe-4f3a-a6d1-e4fa00dc229a")) {                    Plotly.newPlot(                        "e9c58b1e-11fe-4f3a-a6d1-e4fa00dc229a",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Pathology=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Papillary","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Papillary","offsetgroup":"Papillary","orientation":"v","showlegend":true,"x":["Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Pa ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="661bbabd-d34d-4d5a-a00b-31b97066e2e6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("661bbabd-d34d-4d5a-a00b-31b97066e2e6")) {                    Plotly.newPlot(                        "661bbabd-d34d-4d5a-a00b-31b97066e2e6",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Focality=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Uni-Focal","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Uni-Focal","offsetgroup":"Uni-Focal","orientation":"v","showlegend":true,"x":["Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal","Uni-Focal"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Focality=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextr ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="804864d0-8e1c-4647-915d-e6059280fd6d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("804864d0-8e1c-4647-915d-e6059280fd6d")) {                    Plotly.newPlot(                        "804864d0-8e1c-4647-915d-e6059280fd6d",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Risk=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Low","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Low","offsetgroup":"Low","orientation":"v","showlegend":true,"x":["Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Risk=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Intermediate","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Intermediate","offsetgroup":"Intermediate","orientation":"v","showlegend":true,"x":["Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermed ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="62d03928-2fa1-42e7-aedb-43356f292def" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("62d03928-2fa1-42e7-aedb-43356f292def")) {                    Plotly.newPlot(                        "62d03928-2fa1-42e7-aedb-43356f292def",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"T=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"T2","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"T2","offsetgroup":"T2","orientation":"v","showlegend":true,"x":["T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2","T2"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"T=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"T3a","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"T3a","offsetgroup":"T3a","orientation":"v","showlegend":true,"x":["T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a","T3a"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"T=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"T1a","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"T1a","offsetgroup":"T1a","orientation":"v","showlegend":true,"x":["T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a","T1a"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"T=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"T1b","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"T1b","offsetgroup":"T1b","orientation":"v","showlegend":true,"x":["T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b","T1b"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"T=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"T4a","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"T4a","offsetgroup":"T4a","orientation":"v","showlegend":true,"x":[" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e0b6ae10-a4fd-4d24-9c38-91677ca9d314" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e0b6ae10-a4fd-4d24-9c38-91677ca9d314")) {                    Plotly.newPlot(                        "e0b6ae10-a4fd-4d24-9c38-91677ca9d314",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"N=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"N0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"N0","offsetgroup":"N0","orientation":"v","showlegend":true,"x":["N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0","N0"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"N=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"N1b","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"N1b","offsetgroup":"N1b","orientation":"v","showlegend":true,"x":["N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b","N1b"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"N=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"N1a","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"N1a","offsetgroup":"N1a","orientation":"v","showlegend":true,"x":["N1a","N1a","N1a","N1a","N1a","N1a","N1a","N1a","N1a","N1a","N1a","N1a","N1a","N1a","N1a","N1a","N1a","N1a","N1a","N1a","N1a","N1a"],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[ ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5a70da9b-8600-45c9-84f6-99c7039581ac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5a70da9b-8600-45c9-84f6-99c7039581ac")) {                    Plotly.newPlot(                        "5a70da9b-8600-45c9-84f6-99c7039581ac",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"M=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"M0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"M0","offsetgroup":"M0","orientation":"v","showlegend":true,"x":["M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0","M0"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"M=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"M1","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"M1","offsetgroup":"M1","orientation":"v","showlegend":true,"x":["M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1"],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}] ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="14488f63-a880-43a1-af3f-40fe0fc4e59d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("14488f63-a880-43a1-af3f-40fe0fc4e59d")) {                    Plotly.newPlot(                        "14488f63-a880-43a1-af3f-40fe0fc4e59d",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Stage=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"I","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"I","offsetgroup":"I","orientation":"v","showlegend":true,"x":["I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Stage=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"II","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"II","offsetgroup":"II","orientation":"v","showlegend":true,"x":["II","II","II","II","II","II","II","II","II","II","II","II","II","II","II","II","II","II","II","II","II","II","II","II","II","II","II","II","II","II","II","II"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Stage=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"IVB","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"IVB","offsetgroup":"IVB","orientation":"v","showlegend":true,"x":["IVB","IVB","IVB","IVB","IVB","IVB","IVB","IVB","IVB","IVB","IVB"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Stage=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"III","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"III","offsetgroup":"III","orientation":"v","showlegend":true,"x":["III","III","III","III"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Stage=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"IVA","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"IVA","offsetgroup":"IVA","orientation":"v","showlegend":true,"x":["IVA","IVA","IVA"],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ef0bd2bb-598b-4965-9a81-fee5afb0a7da" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ef0bd2bb-598b-4965-9a81-fee5afb0a7da")) {                    Plotly.newPlot(                        "ef0bd2bb-598b-4965-9a81-fee5afb0a7da",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Response=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Excellent","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Excellent","offsetgroup":"Excellent","orientation":"v","showlegend":true,"x":["Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Response=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Structural Incomplete","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Structural Incomplete","offsetgroup":"Structural Incomplete","orientation":"v","showlegend":true,"x":["Structural Incomplete","Structural Incomplete","Structural Incomplete","Structural Incomplete","Structural Incomplete","Structural Incomplete","Structural Incomplete","Structural Incomplete","Structural Incomplete","Structural Incomplete","Structural Incompl ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5d3c3b63-a3b6-4255-b45f-6d34c8eee513" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5d3c3b63-a3b6-4255-b45f-6d34c8eee513")) {                    Plotly.newPlot(                        "5d3c3b63-a3b6-4255-b45f-6d34c8eee513",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Recurred=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"x":["No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Recurred=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Yes","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Yes","offsetgroup":"Yes","orientation":"v","showlegend":true,"x":["Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes"],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.55555555555555 ...

# %%
# DISTRIBUTION OF NUMERICAL FEATURES
for col in numerical_features:
    fig = px.histogram(df, x=col,
                       title=f'DISTRIBUTION OF {col}',
                       histfunc='count',
                       color_discrete_sequence=['skyblue'],
                       nbins=None,
                       )
    fig.update_layout(bargap=0.1)
    fig.update_traces(xbins=dict(
        start=df[col].min(),
        end=df[col].max(),
        size=1
    ))
    fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e6040bb1-e067-472f-8f2e-4ee40269f274" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e6040bb1-e067-472f-8f2e-4ee40269f274")) {                    Plotly.newPlot(                        "e6040bb1-e067-472f-8f2e-4ee40269f274",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"count","hovertemplate":"Age=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"skyblue","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[27,34,30,62,62,52,41,46,51,40,75,59,49,50,76,42,40,44,43,52,41,44,36,70,60,33,43,26,41,37,37,30,36,55,52,37,31,43,40,34,51,45,20,38,38,33,31,31,26,29,43,30,25,27,25,21,43,23,23,43,24,35,54,54,22,38,35,51,22,51,40,69,31,29,30,28,22,29,35,50,27,17,27,40,33,25,73,36,35,31,18,62,62,39,37,26,31,24,57,28,44,42,27,51,33,42,26,24,60,60,31,66,44,32,26,37,33,23,47,28,37,26,28,28,44,31,27,56,63,24,30,31,32,28,51,20,21,32,26,42,28,41,42,49,29,29,25,41,33,27,50,19,35,63,24,36,31,24,33,24,28,22,27,28,29,40,31,55,21,40,38,21,31,30,50,34,45,52,38,67,72,45,45,26,67,56,30,34,50,42,35,23,44,23,26,61,22,31,68,57,27,25,20,33,36,36,40,17,24,38,28,36,50,51,55,31,33,28,48,40,29,20,35,56,20,62,17,21,20,40,38,21,31,34,60,60,62,36,29,33,75,62,56,52,35,34,32,27,52,46,30,32,25,38,31,37,21,34,30,48,31,52,38,41,41,70,19,41,32,35,39,45,46,45,28,31,81,41,56,47,37,32,53,30,34,62,58,55,21,27,46,44,29,26,42,56,51,61,42,34,67,63,67,73,26,30,36,31,40,49,38,27,27,33,32,29,37,48,30,33,80,62,63,60,79,65,35,58,34,56,52,51,31,44,15,29,53,45,38,48,42,23,22,44,31,25,32,82,58,68,37,59,21,73,35,32,54,26,53,35,49,34,80,67,68,71,64,80,56,71,78,51,67,31,62,59,40,46,72,81,72,61,67],"xaxis":"x","yaxis":"y","type":"histogram","xbins":{"end":82,"size":1,"start":15}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.444444444 ...

# %%
# RISK LEVEL vs AGE
# NUMBER OF PATIENTS vs RISK LEVEL
fig = px.box(df,
             x='Risk',
             y='Age',
             color='Risk',
             points='all',
             title='RISK LEVEL BY AGE')
fig.show()

risk_counts = df['Risk'].value_counts().reset_index()
risk_counts.columns = ['Risk Level', 'Count']

fig = px.bar(risk_counts,
             x='Risk Level',
             y='Count',
             text='Count',
             color='Risk Level',
             title='NUMBER OF PATIENTS BY RISK LEVEL')

fig.update_traces(textposition='outside')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ed9a9a29-07dd-4cb8-a822-4807b903f8e2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ed9a9a29-07dd-4cb8-a822-4807b903f8e2")) {                    Plotly.newPlot(                        "ed9a9a29-07dd-4cb8-a822-4807b903f8e2",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"Risk=%{x}\u003cbr\u003eAge=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Low","marker":{"color":"#636efa"},"name":"Low","notched":false,"offsetgroup":"Low","orientation":"v","showlegend":true,"x":["Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low","Low"],"x0":" ","xaxis":"x","y":[27,34,30,62,62,52,41,46,51,40,75,59,49,50,76,42,40,44,43,52,41,44,36,70,60,33,43,26,41,37,37,30,36,55,52,37,31,43,40,34,51,45,20,38,38,33,29,43,30,25,27,25,21,43,23,23,43,24,35,54,54,22,38,35,51,22,51,40,69,31,29,30,28,22,29,35,50,27,17,27,25,73,36,62,39,37,26,31,24,57,28,44,42,27,51,33,42,26,24,60,60,31,66,44,32,26,37,33,23,47,28,37,26,28,28,44,31,27,56,63,24,30,31,32,28,51,20,21,32,26,42,28,41,42,49,29,29,25,41,33,27,50,19,35,63,24,36,31,24,33,24,28,22,27,28,29,40,31,55,21,40,38,21,31,30,50,34,45,52,38,67,72,45,45,26,67,56,30,34,50,42,35,23,44,23,26,61,22,31,68,57,27,25,33,36,36,31,33,28,40,29,35,56,20,62,21,29,33,62,56,52,35,32,27,52,46,30,32,25,38,31,37,21,34,30,48,31,52,38,41,41,70,19,41,32,35,39,45,46,45,28,31,81,21,29,51,42,34,56],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"Risk=%{x}\u003cbr\u003eAge=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Intermediate","marker":{"color":"#EF553B"},"name":"Intermediate","notched":false,"offsetgroup":"Intermediate","orientation":"v","showlegend":true,"x":["Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Intermediate","Inter ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="cdb98f6f-d54d-42b1-af5e-09c4e3378fd6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cdb98f6f-d54d-42b1-af5e-09c4e3378fd6")) {                    Plotly.newPlot(                        "cdb98f6f-d54d-42b1-af5e-09c4e3378fd6",                        [{"alignmentgroup":"True","hovertemplate":"Risk Level=%{x}\u003cbr\u003eCount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Low","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Low","offsetgroup":"Low","orientation":"v","showlegend":true,"text":[249.0],"textposition":"outside","x":["Low"],"xaxis":"x","y":[249],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Risk Level=%{x}\u003cbr\u003eCount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Intermediate","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Intermediate","offsetgroup":"Intermediate","orientation":"v","showlegend":true,"text":[102.0],"textposition":"outside","x":["Intermediate"],"xaxis":"x","y":[102],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Risk Level=%{x}\u003cbr\u003eCount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"High","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"High","offsetgroup":"High","orientation":"v","showlegend":true,"text":[32.0],"textposition":"outside","x":["High"],"xaxis":"x","y":[32],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd378 ...

# %%
# RECURRENCE vs STAGE
stage_order = ['I', 'II', 'III', 'IVA', 'IVB']
df['Stage'] = pd.Categorical(df['Stage'], categories=stage_order, ordered=True)

prop_df = df.groupby('Stage')['Recurred'].value_counts(normalize=True).rename('Proportion').reset_index()

fig = px.bar(prop_df,
             x='Stage',
             y='Proportion',
             color='Recurred',
             barmode='stack',
             text=prop_df['Proportion'].round(2),
             title='RECURRENCE RATIO BY STAGE')
fig.update_traces(textposition='inside')
fig.show()


fig = px.histogram(df,
                   x='Stage',
                   color='Recurred',
                   barmode='group',
                   text_auto=True,
                   title='RECURRENCE COUNT BY STAGE')
fig.show()
# Out:
# <ipython-input-46-1cfe93deed6c>:5: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ea51b9b3-64c3-4085-b612-c84c34efcf9c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ea51b9b3-64c3-4085-b612-c84c34efcf9c")) {                    Plotly.newPlot(                        "ea51b9b3-64c3-4085-b612-c84c34efcf9c",                        [{"alignmentgroup":"True","hovertemplate":"Recurred=No\u003cbr\u003eStage=%{x}\u003cbr\u003eProportion=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"text":[0.8,0.22,0.0,0.0,0.0],"textposition":"inside","x":["I","II","III","IVA","IVB"],"xaxis":"x","y":[0.8048048048048048,0.21875,0.0,0.0,0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Recurred=Yes\u003cbr\u003eStage=%{x}\u003cbr\u003eProportion=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Yes","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Yes","offsetgroup":"Yes","orientation":"v","showlegend":true,"text":[0.2,0.78,1.0,1.0,1.0],"textposition":"inside","x":["I","II","III","IVA","IVB"],"xaxis":"x","y":[0.19519519519519518,0.78125,1.0,1.0,1.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3c875deb-8eb1-4042-96fc-29b678d5800c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c875deb-8eb1-4042-96fc-29b678d5800c")) {                    Plotly.newPlot(                        "3c875deb-8eb1-4042-96fc-29b678d5800c",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Recurred=No\u003cbr\u003eStage=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","II","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","II","I","I","I","I","I","I","I","I","II","II","II","I","I","I","I","I","I","I","II","I","II","I","I","I"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Recurred=Yes\u003cbr\u003eStage=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Yes","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Yes","offsetgroup":"Yes","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","II","II","I","I","I","IVB","I","I","I","I","II","II","II","II","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","I","II","II","II","II","II","II","I","II","I","I","I","I","I","II","I","I","I","I","II","I","I","I","I","I","I","II","II","III","II","I","I","IVB","II","II","I","I","I","I","I","III","III","IVB","IVB","IVB","II","II","III","IVB","II","IVA","II","IVB","IVB","I","II","IVB","IVB","IVB","IVA","IVA"],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444 ...

# %%
# RECURRENCE vs PATHOLOGY
prop_df = df.groupby('Pathology')['Recurred'].value_counts(normalize=True).rename('Proportion').reset_index()
fig = px.bar(prop_df,
             x='Pathology',
             y='Proportion',
             color='Recurred',
             barmode='stack',
             text=prop_df['Proportion'].round(2),
             title='RECURRENCE RATIO BY PATHOLOGY')
fig.update_traces(textposition='inside')
fig.show()

fig = px.histogram(df,
                   x='Pathology',
                   color='Recurred',
                   barmode='group',
                   text_auto=True,
                   title='RECURRENCE COUNT BY PATHOLOGY')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9f41321c-f444-4db1-99d4-8b2244b203f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9f41321c-f444-4db1-99d4-8b2244b203f2")) {                    Plotly.newPlot(                        "9f41321c-f444-4db1-99d4-8b2244b203f2",                        [{"alignmentgroup":"True","hovertemplate":"Recurred=No\u003cbr\u003ePathology=%{x}\u003cbr\u003eProportion=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"text":[0.57,0.7,1.0,0.69],"textposition":"inside","x":["Follicular","Hurthel cell","Micropapillary","Papillary"],"xaxis":"x","y":[0.5714285714285714,0.7,1.0,0.686411149825784],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Recurred=Yes\u003cbr\u003ePathology=%{x}\u003cbr\u003eProportion=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Yes","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Yes","offsetgroup":"Yes","orientation":"v","showlegend":true,"text":[0.43,0.3,0.31],"textposition":"inside","x":["Follicular","Hurthel cell","Papillary"],"xaxis":"x","y":[0.42857142857142855,0.3,0.313588850174216],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fd ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2eb08c8c-4721-4328-8565-084f78df75be" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2eb08c8c-4721-4328-8565-084f78df75be")) {                    Plotly.newPlot(                        "2eb08c8c-4721-4328-8565-084f78df75be",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Recurred=No\u003cbr\u003ePathology=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Micropapillary","Papillary","Follicular","Micropapillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Hurthel cell","Hurthel cell","Hurthel cell","Hurthel cell","Hurthel cell","Follicular","Follicular","Follicular","Follicular","Follicular","Follicular","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Follicular","Papillary","Papillary","Hurthel cell","Hurthel cell","Hurthel cell","Hurthel cell","Follicular","Follicular","Follicular","Follicular","Follicular","Papillary","Papillary","Papillary","Papillary","Papillary","Papillary","Papi ...

# %%
# RECURRENCE vs RESPONSE
prop_df = df.groupby('Response')['Recurred'].value_counts(normalize=True).rename('Proportion').reset_index()
fig = px.bar(prop_df,
             x='Response',
             y='Proportion',
             color='Recurred',
             barmode='stack',
             text=prop_df['Proportion'].round(2),
             title='RECURRENCE RATIO BY RESPONSE')
fig.update_traces(textposition='inside')
fig.show()

fig = px.histogram(df,
                   x='Response',
                   color='Recurred',
                   barmode='group',
                   text_auto=True,
                   title='RECURRENCE COUNT BY RESPONSE')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9906c154-8976-4aba-b4e5-000aca88718d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9906c154-8976-4aba-b4e5-000aca88718d")) {                    Plotly.newPlot(                        "9906c154-8976-4aba-b4e5-000aca88718d",                        [{"alignmentgroup":"True","hovertemplate":"Recurred=No\u003cbr\u003eResponse=%{x}\u003cbr\u003eProportion=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"text":[0.52,1.0,0.89,0.02],"textposition":"inside","x":["Biochemical Incomplete","Excellent","Indeterminate","Structural Incomplete"],"xaxis":"x","y":[0.5217391304347826,0.9951923076923077,0.8852459016393442,0.02197802197802198],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Recurred=Yes\u003cbr\u003eResponse=%{x}\u003cbr\u003eProportion=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Yes","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Yes","offsetgroup":"Yes","orientation":"v","showlegend":true,"text":[0.48,0.0,0.11,0.98],"textposition":"inside","x":["Biochemical Incomplete","Excellent","Indeterminate","Structural Incomplete"],"xaxis":"x","y":[0.4782608695652174,0.004807692307692308,0.11475409836065574,0.978021978021978],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a2429bc8-f919-4f4a-9627-f6219ec0041d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a2429bc8-f919-4f4a-9627-f6219ec0041d")) {                    Plotly.newPlot(                        "a2429bc8-f919-4f4a-9627-f6219ec0041d",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Recurred=No\u003cbr\u003eResponse=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Indeterminate","Excellent","Excellent","Excellent","Excellent","Indeterminate","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Indeterminate","Excellent","Indeterminate","Excellent","Indeterminate","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Indeterminate","Excellent","Excellent","Excellent","Indeterminate","Excellent","Excellent","Excellent","Indeterminate","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Indeterminate","Excellent","Excellent","Excellent","Indeterminate","Excellent","Excellent","Indeterminate","Excellent","Excellent","Excellent","Excellent","Indeterminate","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Biochemical Incomplete","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Indeterminate","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Biochemical Incomplete","Excellent","Biochemical Incomplete","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Biochemical Incomplete","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Indeterminate","Indeterminate","Excellent","Excellent","Excellent","Excellent","Excellent","Biochemical Incomplete","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Indeterminate","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Indeterminate","Indeterminate","Excellent","Excellent","Excellent","Excellent","Excellent","Indeterminate","Excellent","Biochemical Incomplete","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Excellent","Indeterminate","Indeterminate","Indeterminate","Excellent","Excellent","Excellent","Indeterminate","Indeterminate","Indeterminate","Indeterminate","Excellent","Indeterminate","Indeterminate","Indeterminate","Excellent","Indeterminate","Excellent","Indeterminate","Biochemical Incomplete","Excellent","Indeterminate","Excellent","Excellent","Structural Incomplete","Excellent","Excellent","Indeterminate","Excellent","Biochemical Incomplete","Indeterminate","Excellent","Biochemical Incomplete","Excellent","Biochemical Incomplete","Indeterminate","Excellent","Ind ...

# %% [markdown]
# ### FEATURE ENGINEERING

# %%
# LABEL ENCODING
le = LabelEncoder()
for col in df.select_dtypes(include=['object', 'category']).columns:
    df[col] = le.fit_transform(df[col])

# %%
df.head()
# Out:
#    Age  Gender  Hx Radiothreapy  Adenopathy  Pathology  Focality  Risk  T  N  \
# 0   27       0                0           3          2         1     2  0  0
# 1   34       0                0           3          2         1     2  0  0
# 2   30       0                0           3          2         1     2  0  0
# 3   62       0                0           3          2         1     2  0  0
# 4   62       0                0           3          2         0     2  0  0
#
#    M  Stage  Response  Recurred
# 0  0      0         2         0
# 1  0      0         1         0
# 2  0      0         1         0
# 3  0      0         1         0
# 4  0      0         1         0

# %%
correlation_matrix = df.corr()

# %%
# CORRELATION MATRIX
fig = px.imshow(
    correlation_matrix,
    text_auto=".2f",
    color_continuous_scale="RdBu",
    title="CORRELATION MATRIX"
)

fig.update_layout(
    width=1000,
    height=800,
    margin=dict(l=50, r=50, t=50, b=50)
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="33fe7a87-bda8-4ecd-aaba-0afdad6be495" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("33fe7a87-bda8-4ecd-aaba-0afdad6be495")) {                    Plotly.newPlot(                        "33fe7a87-bda8-4ecd-aaba-0afdad6be495",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z:.2f}","x":["Age","Gender","Hx Radiothreapy","Adenopathy","Pathology","Focality","Risk","T","N","M","Stage","Response","Recurred"],"y":["Age","Gender","Hx Radiothreapy","Adenopathy","Pathology","Focality","Risk","T","N","M","Stage","Response","Recurred"],"z":[[1.0,0.18645669992092317,0.17658840293763317,-0.10150860378123439,-0.1596886195910342,-0.22384653279532782,-0.29555552414799247,0.24266964146815861,0.06124317260166043,0.23540065049140496,0.5268623631411972,0.18064331494842553,0.25889701090156786],[0.18645669992092317,1.0,0.23586543353361758,-0.21595311890695698,-0.023538964802508066,-0.207634177812268,-0.2952294719675314,0.2719486193060566,0.23876574560938538,0.2115395196740525,0.2502152147540799,0.2728683293764286,0.3281891547563243],[0.17658840293763317,0.23586543353361758,1.0,-0.05778086109679195,-0.10646905244747315,-0.1024154349700283,-0.27205559516482974,0.22579373199803587,0.09553451257207946,0.43021417261116346,0.4619008926605239,0.10590844692018893,0.17440671679872705],[-0.10150860378123439,-0.21595311890695698,-0.05778086109679195,1.0,-0.015111339159774952,0.17573215455431324,0.182048716439942,-0.20764839518082415,-0.1542805131181897,-0.080490598548605,-0.15006891124985003,-0.19068584305664463,-0.182530419761745],[-0.1596886195910342,-0.023538964802508066,-0.10646905244747315,-0.015111339159774952,1.0,0.030218795160332625,0.020350640589402138,0.007605222728520743,0.2413810724616422,-0.09597379338439023,-0.11117080474719365,-0.019871920910536002,0.0032717219768206435],[-0.22384653279532782,-0.207634177812268,-0.1024154349700283,0.17573215455431324,0.030218795160332625,1.0,0.4506154588534556,-0.4548316278667335,-0.37669221031693645,-0.2219311847316124,-0.3318923144373834,-0.35652068001867493,-0.38377627588386526],[-0.29555552414799247,-0.2952294719675314,-0.27205559516482974,0.182048716439942,0.020350640589402138,0.4506154588534556,1.0,-0.680255454810556,-0.6967644462666105,-0.5031433368736752,-0.619414500606077,-0.6060712589503027,-0.7333758705566537],[0.24266964146815861,0.2719486193060566,0.22579373199803587,-0.20764839518082415,0.007605222728520743,-0.4548316278667335,-0.680255454810556,1.0,0.4587006008965517,0.38848961040461477,0.5383088095434646,0.4595971494585666,0.5562010816974664],[0.06124317260166043,0.23876574560938538,0.09553451257207946,-0.1542805131181897,0.2413810724616422,-0.37669221031693645,-0.6967644462666105,0.4587006008965517,1.0,0.2192691569516942,0.27428096078138275,0.5838090862363217,0.632323477752586],[0.23540065049140496,0.2115395196740525,0.43021417261116346,-0.080490598548605,-0.09597379338439023,-0.2219311847316124,-0.5031433368736752,0.38848961040461477,0.2192691569516942,1.0,0.6810192562134239,0.3050772707153054,0.3543596707523413],[0.5268623631411972,0.2502152147540799,0.4619008926605239,-0.15006891124985003,-0.11117080474719365,-0.3318923144373834,-0.619414500606077,0.5383088095434646,0.27428096078138275,0.6810192562134239,1.0,0.3378751197280715,0.44913731445334537],[0.18064331494842553,0.2728683293764286,0.10590844692018893,-0.19068584305664463,-0.019871920910536002,-0.35652068001867493,-0.6060712589503027,0.4595971494585666,0.5838090862363217,0.3050772707153054,0.3378751197280715,1.0,0.7089566110550052],[0.25889701090156786,0.3281891547563243,0.17440671679872705,-0.182530419761745,0.0032717219768206435,-0.38377627588386526,-0.7333758705566537,0.5562010816974664,0.632323 ...

# %%
# CORRELATION VALUES
corr = df.corr(numeric_only=True)
print(corr['Recurred'].sort_values(ascending=False))
# Out:
# Recurred           1.000000
# Response           0.708957
# N                  0.632323
# T                  0.556201
# Stage              0.449137
# M                  0.354360
# Gender             0.328189
# Age                0.258897
# Hx Radiothreapy    0.174407
# Pathology          0.003272
# Adenopathy        -0.182530
# Focality          -0.383776
# Risk              -0.733376
# Name: Recurred, dtype: float64

# %%
# DEFINE FEATURES AND TARGET
X = df.drop(['Recurred', 'Risk', 'Response'], axis=1)
y = df['Recurred']

# %%
# FEATURE SCALING
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# SPLIT DATASET
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, stratify=y, random_state=42)

# %% [markdown]
# ### APPLICATION OF MACHINE LEARNING MODELS

# %%
# LOGISTIC REGRESSION MODEL
lr = LogisticRegression()
lr.fit(X_train, y_train)
predict_lr = lr.predict(X_test)
print("Logistic Regression Report:\n", classification_report(y_test, predict_lr))
# Out:
# Logistic Regression Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.91      0.93        55
#            1       0.80      0.91      0.85        22
#
#     accuracy                           0.91        77
#    macro avg       0.88      0.91      0.89        77
# weighted avg       0.92      0.91      0.91        77

# %%
# RANDOM FOREST CLASSIFIER MODEL
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
predict_rf = rf.predict(X_test)
print("Random Forest Report:\n", classification_report(y_test, predict_rf))
# Out:
# Random Forest Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.95      0.92        55
#            1       0.84      0.73      0.78        22
#
#     accuracy                           0.88        77
#    macro avg       0.87      0.84      0.85        77
# weighted avg       0.88      0.88      0.88        77

# %%
# XGBOOST MODEL
xgb = XGBClassifier(use_label_encoder=False, eval_metric='logloss')
xgb.fit(X_train, y_train)
predict_xgb = xgb.predict(X_test)
print("XGBoost Report:\n", classification_report(y_test, predict_xgb))
# Out:
# XGBoost Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.89      0.91        55
#            1       0.75      0.82      0.78        22
#
#     accuracy                           0.87        77
#    macro avg       0.84      0.85      0.85        77
# weighted avg       0.87      0.87      0.87        77
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning:
#
# [20:03:50] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.

# %% [markdown]
# ### MODEL EVALUATION

# %%
# METRICS BY MODEL
reports = []

report_lr = classification_report(y_test, predict_lr, output_dict=True)
acc_lr = accuracy_score(y_test, predict_lr)
reports.append({'Model': 'Logistic Regression',
                'Precision': report_lr['macro avg']['precision'],
                'Recall': report_lr['macro avg']['recall'],
                'F1-Score': report_lr['macro avg']['f1-score'],
                'Accuracy': acc_lr})

report_rf = classification_report(y_test, predict_rf, output_dict=True)
acc_rf = accuracy_score(y_test, predict_rf)
reports.append({'Model': 'Random Forest',
                'Precision': report_rf['macro avg']['precision'],
                'Recall': report_rf['macro avg']['recall'],
                'F1-Score': report_rf['macro avg']['f1-score'],
                'Accuracy': acc_rf})

report_xgb = classification_report(y_test, predict_xgb, output_dict=True)
acc_xgb = accuracy_score(y_test, predict_xgb)
reports.append({'Model': 'XGBoost',
                'Precision': report_xgb['macro avg']['precision'],
                'Recall': report_xgb['macro avg']['recall'],
                'F1-Score': report_xgb['macro avg']['f1-score'],
                'Accuracy': acc_xgb})

df_metrics = pd.DataFrame(reports)

df_melted = df_metrics.melt(id_vars='Model', var_name='Metric', value_name='Score')

fig = px.bar(df_melted, x='Model', y='Score', color='Metric', barmode='group',
             text_auto='.2f', title='Model Comparison: Accuracy, Precision, Recall & F1-score (Macro Avg)')
fig.update_layout(yaxis=dict(range=[0.8, 1.05]))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6d7bc6e6-11d8-4d56-a5f2-3df5601889b5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6d7bc6e6-11d8-4d56-a5f2-3df5601889b5")) {                    Plotly.newPlot(                        "6d7bc6e6-11d8-4d56-a5f2-3df5601889b5",                        [{"alignmentgroup":"True","hovertemplate":"Metric=Precision\u003cbr\u003eModel=%{x}\u003cbr\u003eScore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Precision","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Precision","offsetgroup":"Precision","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.2f}","x":["Logistic Regression","Random Forest","XGBoost"],"xaxis":"x","y":[0.8807692307692307,0.8693284936479129,0.8372641509433962],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Metric=Recall\u003cbr\u003eModel=%{x}\u003cbr\u003eScore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Recall","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Recall","offsetgroup":"Recall","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.2f}","x":["Logistic Regression","Random Forest","XGBoost"],"xaxis":"x","y":[0.9090909090909091,0.8363636363636364,0.8545454545454545],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Metric=F1-Score\u003cbr\u003eModel=%{x}\u003cbr\u003eScore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"F1-Score","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"F1-Score","offsetgroup":"F1-Score","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.2f}","x":["Logistic Regression","Random Forest","XGBoost"],"xaxis":"x","y":[0.8928216345197852,0.8504208935894668,0.8450080515297906],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Metric=Accuracy\u003cbr\u003eModel=%{x}\u003cbr\u003eScore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Accuracy","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Accuracy","offsetgroup":"Accuracy","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.2f}","x":["Logistic Regression","Random Forest","XGBoost"],"xaxis":"x","y":[0.9090909090909091,0.8831168831168831,0.8701298701298701],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201 ...

# %% [markdown]
# ### FINAL ANALYSIS, INSIGHTS AND CONCLUSION

# %% [markdown]
# ## 🔍 Final Analysis and Key Findings
#
# ### 1. Are thyroid cancer recurrences more common in men or women?
# While most patients in the dataset are women, **men show a higher proportion of recurrence**. This suggests that male patients may be at increased risk and deserve closer monitoring.
#
# ### 2. How does age affect recurrence risk?
# There is a **moderate positive correlation (0.26)** between age and recurrence. Older patients tend to experience recurrence more frequently, although age alone is not the most dominant factor.
#
# ### 3. Can recurrence be predicted based on tumor staging and pathology?
# Yes. Variables such as **Stage, T, N, M, and Pathology** all show relevant patterns:
# - Recurrence rates increase with higher cancer stages (Stage IV).
# - Some pathology types like **Papillary** and **Hurthel cell** are more frequently associated with recurrence.
# - These patterns were confirmed by predictive models using these features.
#
# ### 4. What is the relationship between treatment response and recurrence?
# A very clear one: patients with **“Structural Incomplete”** or **“Biochemical Incomplete”** responses have significantly higher recurrence rates, while those with an **“Excellent”** response rarely relapse. `Response` shows the **strongest correlation (0.71)** with recurrence.
#
# ## 📊 Key Insights
# - `Risk` classification shows the **strongest negative correlation (-0.73)** with recurrence. Higher-risk patients are much more likely to relapse.
# - **Logistic Regression** delivered the best balance between precision and recall.
# - **XGBoost** performed more balanced across both classes (recurred / not recurred), while **Random Forest** performed slightly better for non-recurrences.
#
# ## ✅ Overall Conclusion
#
# The results confirm that it is possible to accurately predict thyroid cancer recurrence using clinical data. Key variables like **tumor stage, treatment response, and risk** allow for early identification of high-risk patients. These models could support clinical decision-making and personalized follow-up strategies.
#
# **Author:** Adrian Zambrana · April 2025
